# %%
from helpers import *
import seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Load data
df = pd.DataFrame.from_csv("../data/data.csv")

# %%
seaborn.pairplot(df)J

# %%
plt.figure(figsize=(10,10))

flt = df[(df['likes']<2000)&(df['audios']<8000)]

plt.scatter(flt['likes'],flt['audios'],alpha=0.04)

# %%
plt.hist(df['likes'],log=True,bins=20)
# Out:
# (array([  5.41400000e+03,   3.64000000e+02,   1.37000000e+02,
#           5.30000000e+01,   3.30000000e+01,   2.20000000e+01,
#           3.20000000e+01,   1.20000000e+01,   1.20000000e+01,
#           5.00000000e+00,   7.00000000e+00,   4.00000000e+00,
#           3.00000000e+00,   6.00000000e+00,   2.00000000e+00,
#           2.00000000e+00,   0.00000000e+00,   3.00000000e+00,
#           0.00000000e+00,   3.00000000e+00]),
#  array([  3.00000000e+00,   8.30690000e+03,   1.66108000e+04,
#           2.49147000e+04,   3.32186000e+04,   4.15225000e+04,
#           4.98264000e+04,   5.81303000e+04,   6.64342000e+04,
#           7.47381000e+04,   8.30420000e+04,   9.13459000e+04,
#           9.96498000e+04,   1.07953700e+05,   1.16257600e+05,
#           1.24561500e+05,   1.32865400e+05,   1.41169300e+05,
#           1.49473200e+05,   1.57777100e+05,   1.66081000e+05]),
#  <a list of 20 Patch objects>)
